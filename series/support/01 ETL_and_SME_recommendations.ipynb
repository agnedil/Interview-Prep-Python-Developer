# %% [markdown]
# # Data ETL (Extract, Transform, Load)

# %%
import math
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from copy import deepcopy
from sklearn.preprocessing import StandardScaler
# %matplotlib inline
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)

# %%
# measured depth cutoffs, source data filenames, fields, parts of field
dict_wells = {
              'MC348-3ST1': [(25654, 25834), 'MC348-3ST1 Appomattox NE_LQC.csv', 'Appomattox',   'NE'  ],
              'MC391-1'   : [(25402, 26080), 'MC391-1 Appomattox SW_LQC.csv',    'Appomattox',   'SW'  ],
              'MC392-1'   : [(24463, 24990), 'MC392-1 Appomattox SE_LQC.csv',    'Appomattox',   'SE'  ],
              'MC392-1ST1': [(25987, 26809), 'MC392-1ST1 Appomattox SE_LQC.csv', 'Appomattox',   'SE'  ],
              'MC393-1'   : [(25378, 26385), 'MC393-1 Vicksburg A_LQC.csv',      'Vicksburg A',  np.nan],
              'MC525-2'   : [(25113, 26101), 'MC525-2 Rydberg Deep_LQC.csv',     'Rydberg Deep', np.nan],
              'MC612-1BP1': [(27611, 28695), 'MC612-1BP1 Dover_LQC.csv',         'Dover',        np.nan]
             }

# %%
# get header into one line
rename_map =   {'MD': 'MD, ft',
                'wellName': 'wellName_old',
                'DENSITY': 'DENSITY, g/cm3',
                'DTC': 'DTC, us/ft',             # delta time compressional
                'DTS': 'DTS, US/F',              # delta time shear
                'FLD': 'FLD, unitless',          # fluid
                'GR': 'GR, gAPI',
                'NEUTRON': 'NEUTRON, CFCF',
                'NMR_BW': 'NMR_BW, v/v',         # bound water
                'NMR_CBW': 'NMR_CBW, v/v',       # clay bound water
                'NMR_FF': 'NMR_FF, v/v',         # free fluid
                'NMR_TPOR': 'NMR_TPOR, v/v',     # total porosity
                'RDEEP': 'RDEEP, ohm.m',         # less affected by drilling process (we will use this one)
                'RMEDIUM': 'RMEDIUM, ohm.m',     #
                'RSHALLOW': 'RSHALLOW, ohm.m',   # affected by drilling process the most
                'TVD': 'TVD, ft',
                'TVDBML': 'TVDBML, ft',
                'TVDSS': 'TVDSS, ft'}            # When comparing between well – TVD is more useful (TVDSS?)

# %%
# f(x) to create, if missing, and move RMEDIUM and RSHALLOW to the end (to have the same sequence of columns in all df)
# move least interesting columns to the end; 'wellName_old' renamed and moved to and as there is shorter version 'Well name'
# 'datasetName' has only one unique value - keeping it as historical
def rearrange_columns(df):
    
    start_cols = ['Well name', 'Field', 'Field part']
    end_cols = ['Filename', 'wellName_old', 'datasetName', 'RMEDIUM, ohm.m', 'RSHALLOW, ohm.m']
        
    for col in start_cols + end_cols:
        if col not in df:
            df[col] = np.nan
    
    return df[start_cols + [c for c in df if c not in end_cols and c not in start_cols] + end_cols]

# %%
# read Excel files with data
wdir = 'csv/'
data = []
for key in dict_wells:
    df = pd.read_csv(wdir + dict_wells[key][1], dtype='str')    
    df = df.rename(columns = rename_map)
    df = df.drop(0)
    #df = df.replace(np.nan, 'None')
    df = df.replace('-9999', np.nan)
    df = df.apply(pd.to_numeric, errors='ignore')
    df = df[(df['MD, ft'] >= dict_wells[key][0][0]) & (df['MD, ft'] <= dict_wells[key][0][1])]
    df['Well name'] = key
    df['Field'] = dict_wells[key][2]
    df['Field part'] = dict_wells[key][3]
    df['Filename'] = dict_wells[key][1]
    df = rearrange_columns(df)
        
    print('WELL {}'.format(key))
    print(df.dtypes)
    print('*'*100)
        
    data.append(df)
# Out:
# WELL MC348-3ST1
# Well name           object
# Field               object
# Field part          object
# MD, ft             float64
# DENSITY, g/cm3     float64
# DTC, us/ft         float64
# DTS, US/F          float64
# FLD, unitless      float64
# GR, gAPI           float64
# NEUTRON, CFCF      float64
# NMR_BW, v/v        float64
# NMR_CBW, v/v       float64
# NMR_FF, v/v        float64
# NMR_TPOR, v/v      float64
# RDEEP, ohm.m       float64
# TVD, ft            float64
# TVDBML, ft         float64
# TVDSS, ft          float64
# Filename            object
# wellName_old        object
# datasetName         object
# RMEDIUM, ohm.m     float64
# RSHALLOW, ohm.m    float64
# dtype: object
# ****************************************************************************************************
# WELL MC391-1
# Well name           object
# Field               object
# Field part          object
# MD, ft             float64
# DENSITY, g/cm3     float64
# DTC, us/ft         float64
# DTS, US/F          float64
# FLD, unitless        int64
# GR, gAPI           float64
# NEUTRON, CFCF      float64
# NMR_BW, v/v        float64
# NMR_CBW, v/v       float64
# NMR_FF, v/v        float64
# NMR_TPOR, v/v      float64
# RDEEP, ohm.m       float64
# TVD, ft            float64
# TVDBML, ft         float64
# TVDSS, ft          float64
# Filename            object
# wellName_old        object
# datasetName         object
# RMEDIUM, ohm.m     float64
# RSHALLOW, ohm.m    float64
# dtype: object
# ****************************************************************************************************
# WELL MC392-1
# Well name           object
# Field               object
# Field part          object
# MD, ft             float64
# DENSITY, g/cm3     float64
# DTC, us/ft         float64
# DTS, US/F          float64
# FLD, unitless      float64
# GR, gAPI           float64
# NEUTRON, CFCF      float64
# NMR_BW, v/v        float64
# NMR_CBW, v/v       float64
# NMR_FF, v/v        float64
# NMR_TPOR, v/v      float64
# RDEEP, ohm.m       float64
# TVD, ft            float64
# TVDBML, ft         float64
# TVDSS, ft          float64
# Filename            object
# wellName_old        object
# datasetName         object
# RMEDIUM, ohm.m     float64
# RSHALLOW, ohm.m    float64
# dtype: object
# ****************************************************************************************************
# WELL MC392-1ST1
# Well name           object
# Field               object
# Field part          object
# MD, ft             float64
# DENSITY, g/cm3     float64
# DTC, us/ft         float64
# DTS, US/F          float64
# FLD, unitless      float64
# GR, gAPI           float64
# NEUTRON, CFCF      float64
# NMR_BW, v/v        float64
# NMR_CBW, v/v       float64
# NMR_FF, v/v        float64
# NMR_TPOR, v/v      float64
# RDEEP, ohm.m       float64
# TVD, ft            float64
# TVDBML, ft         float64
# TVDSS, ft          float64
# Filename            object
# wellName_old        object
# datasetName         object
# RMEDIUM, ohm.m     float64
# RSHALLOW, ohm.m    float64
# dtype: object
# ****************************************************************************************************
# WELL MC393-1
# Well name           object
# Field               object
# Field part         float64
# MD, ft             float64
# DENSITY, g/cm3     float64
# DTC, us/ft         float64
# DTS, US/F          float64
# FLD, unitless      float64
# GR, gAPI           float64
# NEUTRON, CFCF      float64
# NMR_BW, v/v        float64
# NMR_CBW, v/v       float64
# NMR_FF, v/v        float64
# NMR_TPOR, v/v      float64
# RDEEP, ohm.m       float64
# TVD, ft            float64
# TVDBML, ft         float64
# TVDSS, ft          float64
# Filename            object
# wellName_old        object
# datasetName         object
# RMEDIUM, ohm.m     float64
# RSHALLOW, ohm.m    float64
# dtype: object
# ****************************************************************************************************
# WELL MC525-2
# Well name           object
# Field               object
# Field part         float64
# MD, ft             float64
# DENSITY, g/cm3     float64
# DTC, us/ft         float64
# DTS, US/F          float64
# FLD, unitless      float64
# GR, gAPI           float64
# NEUTRON, CFCF      float64
# NMR_BW, v/v        float64
# NMR_CBW, v/v       float64
# NMR_FF, v/v        float64
# NMR_TPOR, v/v      float64
# RDEEP, ohm.m       float64
# TVD, ft            float64
# TVDBML, ft         float64
# TVDSS, ft          float64
# Filename            object
# wellName_old        object
# datasetName         object
# RMEDIUM, ohm.m     float64
# RSHALLOW, ohm.m    float64
# dtype: object
# ****************************************************************************************************
# WELL MC612-1BP1
# Well name           object
# Field               object
# Field part         float64
# MD, ft             float64
# DENSITY, g/cm3     float64
# DTC, us/ft         float64
# DTS, US/F          float64
# FLD, unitless        int64
# GR, gAPI           float64
# NEUTRON, CFCF      float64
# NMR_BW, v/v        float64
# NMR_CBW, v/v       float64
# NMR_FF, v/v        float64
# NMR_TPOR, v/v      float64
# RDEEP, ohm.m       float64
# TVD, ft            float64
# TVDBML, ft         float64
# TVDSS, ft          float64
# Filename            object
# wellName_old        object
# datasetName         object
# RMEDIUM, ohm.m     float64
# RSHALLOW, ohm.m    float64
# dtype: object
# ****************************************************************************************************

# %%
# Normalize neutron porosity to fractions if it's in percentage
for df in data:
    if df['NEUTRON, CFCF'].max() > 1:
        df['NEUTRON, CFCF'] = df['NEUTRON, CFCF'] / 100
    print(df['NEUTRON, CFCF'].min(), df['NEUTRON, CFCF'].max())
# Out:
# 0.134075 0.251625
# 0.11034700000000001 0.34739000000000003
# 0.11412 0.32618
# 0.09367353 0.3542884
# 0.16653300000000001 0.385244
# 0.1879767 0.3121433
# 0.15607079999999998 0.3502145

# %%
print('Shape of files for each well:')
for df in data:
    print('\t', df.shape)

data = pd.concat(data).reset_index(drop=True)
print('Final shape:', data.shape)
# Out:
# Shape of files for each well:
# 	 (721, 23)
# 	 (2713, 23)
# 	 (1055, 23)
# 	 (3286, 23)
# 	 (4029, 23)
# 	 (1977, 23)
# 	 (2175, 23)
# Final shape: (15956, 23)

# %%
# Matt Knuth: Negative values there don’t have any meaning. Typically they would be very low values
# that have been made negative by temperature correction
data.loc[data['NMR_FF, v/v'] < 0, 'NMR_FF, v/v'] = 0

# %%
# Matt Knuth: take the log10 of resistivity
def to_log(value):
    
    if pd.isnull(value):
        return value
    else:
        return math.log10(value)
    
data['RDEEP, ohm.m'] = data['RDEEP, ohm.m'].apply(lambda x: to_log(x))
data['RMEDIUM, ohm.m'] = data['RMEDIUM, ohm.m'].apply(lambda x: to_log(x))
data['RSHALLOW, ohm.m'] = data['RSHALLOW, ohm.m'].apply(lambda x: to_log(x))

# %%
# DESCRIBE COLUMNS
def describe_columns(df):
    
    for col in df.columns:
        print('\n{}\n\tdtype: {}\n\tAll: {}\n\tUnique: {}\n\tMissing: {}'.format(col,
                                                                              df[~(df[col].isna())][col].dtype,
                                                                              len(df[col].tolist()),
                                                                              len(df[col].unique()),
                                                                              df[col].isna().sum()))
        if df[col].dtype == 'float64':
            print('\tMin:', df[col].min())
            print('\tMax:', df[col].max())
            print('\tMean: {}\n'.format(df[col].mean()))
        print(df[col].value_counts())
        print('*'*100)

# %%
data.head(50)
# Out:
#      Well name       Field Field part    MD, ft  DENSITY, g/cm3  DTC, us/ft  \
# 0   MC348-3ST1  Appomattox         NE  25654.00          3.1089    66.67333
# 1   MC348-3ST1  Appomattox         NE  25654.25          3.1126    66.94559
# 2   MC348-3ST1  Appomattox         NE  25654.50          3.0757    67.21785
# 3   MC348-3ST1  Appomattox         NE  25654.75          3.0079    67.48043
# 4   MC348-3ST1  Appomattox         NE  25655.00          2.9167    67.74301
# 5   MC348-3ST1  Appomattox         NE  25655.25          2.7429    67.84351
# 6   MC348-3ST1  Appomattox         NE  25655.50          2.6334    67.94402
# 7   MC348-3ST1  Appomattox         NE  25655.75          2.5835    69.30020
# 8   MC348-3ST1  Appomattox         NE  25656.00          2.5735    70.65639
# 9   MC348-3ST1  Appomattox         NE  25656.25          2.5424    72.24492
# 10  MC348-3ST1  Appomattox         NE  25656.50          2.4213    73.83344
# 11  MC348-3ST1  Appomattox         NE  25656.75          2.3537    74.09697
# 12  MC348-3ST1  Appomattox         NE  25657.00          2.3294    74.36050
# 13  MC348-3ST1  Appomattox         NE  25657.25          2.3233    74.87627
# 14  MC348-3ST1  Appomattox         NE  25657.50          2.3446    75.39204
# 15  MC348-3ST1  Appomattox         NE  25657.75          2.3914    75.69860
# 16  MC348-3ST1  Appomattox         NE  25658.00          2.4163    76.00517
# 17  MC348-3ST1  Appomattox         NE  25658.25          2.3892    76.31676
# 18  MC348-3ST1  Appomattox         NE  25658.50          2.3352    76.62835
# 19  MC348-3ST1  Appomattox         NE  25658.75          2.3079    77.19140
# 20  MC348-3ST1  Appomattox         NE  25659.00          2.2997    77.75445
# 21  MC348-3ST1  Appomattox         NE  25659.25          2.2914    78.59444
# 22  MC348-3ST1  Appomattox         NE  25659.50          2.2776    79.43443
# 23  MC348-3ST1  Appomattox         NE  25659.75          2.2692    79.35886
# 24  MC348-3ST1  Appomattox         NE  25660.00          2.2612    79.28328
# 25  MC348-3ST1  Appomattox         NE  25660.25          2.2595    79.20799
# 26  MC348-3ST1  Appomattox         NE  25660.50          2.2635    79.13271
# 27  MC348-3ST1  Appomattox         NE  25660.75          2.2670    79.04211
# 28  MC348-3ST1  Appomattox         NE  25661.00          2.2657    78.95152
# 29  MC348-3ST1  Appomattox         NE  25661.25          2.2621    79.18352
# 30  MC348-3ST1  Appomattox         NE  25661.50          2.2673    79.41550
# 31  MC348-3ST1  Appomattox         NE  25661.75          2.2779    79.44810
# 32  MC348-3ST1  Appomattox         NE  25662.00          2.2747    79.48071
# 33  MC348-3ST1  Appomattox         NE  25662.25          2.2689    79.51340
# 34  MC348-3ST1  Appomattox         NE  25662.50          2.2605    79.54608
# 35  MC348-3ST1  Appomattox         NE  25662.75          2.2510    79.57879
# 31    17891.63   25147.63  MC348-3ST1 Appomattox NE_LQC.csv
# 32    17891.85   25147.85  MC348-3ST1 Appomattox NE_LQC.csv
# 33    17892.07   25148.07  MC348-3ST1 Appomattox NE_LQC.csv
# 34    17892.29   25148.29  MC348-3ST1 Appomattox NE_LQC.csv
# 35    17892.51   25148.51  MC348-3ST1 Appomattox NE_LQC.csv
# 36    17892.73   25148.73  MC348-3ST1 Appomattox NE_LQC.csv
# 37    17892.95   25148.95  MC348-3ST1 Appomattox NE_LQC.csv
# 38    17893.17   25149.17  MC348-3ST1 Appomattox NE_LQC.csv
# 39    17893.39   25149.39  MC348-3ST1 Appomattox NE_LQC.csv
# 40    17893.61   25149.61  MC348-3ST1 Appomattox NE_LQC.csv
# 41    17893.83   25149.83  MC348-3ST1 Appomattox NE_LQC.csv
# 42    17894.05   25150.05  MC348-3ST1 Appomattox NE_LQC.csv
# 43    17894.27   25150.27  MC348-3ST1 Appomattox NE_LQC.csv
# 44    17894.49   25150.49  MC348-3ST1 Appomattox NE_LQC.csv
# 45    17894.71   25150.71  MC348-3ST1 Appomattox NE_LQC.csv
# 46    17894.93   25150.93  MC348-3ST1 Appomattox NE_LQC.csv
# 47    17895.15   25151.15  MC348-3ST1 Appomattox NE_LQC.csv
# 48    17895.37   25151.37  MC348-3ST1 Appomattox NE_LQC.csv
# 49    17895.59   25151.59  MC348-3ST1 Appomattox NE_LQC.csv
#
#                 wellName_old datasetName  RMEDIUM, ohm.m  RSHALLOW, ohm.m
# 0   MC348-3ST1 Appomattox NE         LQC        1.424346              NaN
# 1   MC348-3ST1 Appomattox NE         LQC        1.416532              NaN
# 2   MC348-3ST1 Appomattox NE         LQC        1.253025              NaN
# 3   MC348-3ST1 Appomattox NE         LQC        1.145016              NaN
# 4   MC348-3ST1 Appomattox NE         LQC        1.094094              NaN
# 5   MC348-3ST1 Appomattox NE         LQC        1.077713              NaN
# 6   MC348-3ST1 Appomattox NE         LQC        1.076939              NaN
# 7   MC348-3ST1 Appomattox NE         LQC        1.044438              NaN
# 8   MC348-3ST1 Appomattox NE         LQC        1.016076              NaN
# 9   MC348-3ST1 Appomattox NE         LQC        1.000287              NaN
# 10  MC348-3ST1 Appomattox NE         LQC        1.002861              NaN
# 11  MC348-3ST1 Appomattox NE         LQC        1.018829              NaN
# 12  MC348-3ST1 Appomattox NE         LQC        1.009289              NaN
# 13  MC348-3ST1 Appomattox NE         LQC        0.992576              NaN
# 14  MC348-3ST1 Appomattox NE         LQC        0.983789              NaN
# 15  MC348-3ST1 Appomattox NE         LQC        0.972892              NaN
# 16  MC348-3ST1 Appomattox NE         LQC        0.963528              NaN
# 17  MC348-3ST1 Appomattox NE         LQC        0.958220              NaN
# 18  MC348-3ST1 Appomattox NE         LQC        0.947061              NaN
# 19  MC348-3ST1 Appomattox NE         LQC        0.941243              NaN
# 20  MC348-3ST1 Appomattox NE         LQC        0.931666              NaN
# 21  MC348-3ST1 Appomattox NE         LQC        0.914782              NaN
# 22  MC348-3ST1 Appomattox NE         LQC        0.897863              NaN
# 23  MC348-3ST1 Appomattox NE         LQC        0.884648              NaN
# 24  MC348-3ST1 Appomattox NE         LQC        0.870105              NaN
# 25  MC348-3ST1 Appomattox NE         LQC        0.856022              NaN
# 26  MC348-3ST1 Appomattox NE         LQC        0.844396              NaN
# 27  MC348-3ST1 Appomattox NE         LQC        0.824828              NaN
# 28  MC348-3ST1 Appomattox NE         LQC        0.806580              NaN
# 29  MC348-3ST1 Appomattox NE         LQC        0.789827              NaN
# 30  MC348-3ST1 Appomattox NE         LQC        0.771463              NaN
# 31  MC348-3ST1 Appomattox NE         LQC        0.756986              NaN
# 32  MC348-3ST1 Appomattox NE         LQC        0.740307              NaN
# 33  MC348-3ST1 Appomattox NE         LQC        0.723882              NaN
# 34  MC348-3ST1 Appomattox NE         LQC        0.698788              NaN
# 35  MC348-3ST1 Appomattox NE         LQC        0.681937              NaN
# 36  MC348-3ST1 Appomattox NE         LQC        0.667770              NaN
# 37  MC348-3ST1 Appomattox NE         LQC        0.647031              NaN
# 38  MC348-3ST1 Appomattox NE         LQC        0.626792              NaN
# 39  MC348-3ST1 Appomattox NE         LQC        0.610543              NaN
# 40  MC348-3ST1 Appomattox NE         LQC        0.586621              NaN
# 41  MC348-3ST1 Appomattox NE         LQC        0.563244              NaN
# 42  MC348-3ST1 Appomattox NE         LQC        0.551670              NaN
# 43  MC348-3ST1 Appomattox NE         LQC        0.534635              NaN
# 44  MC348-3ST1 Appomattox NE         LQC        0.509256              NaN
# 45  MC348-3ST1 Appomattox NE         LQC        0.480539              NaN
# 46  MC348-3ST1 Appomattox NE         LQC        0.468392              NaN
# 47  MC348-3ST1 Appomattox NE         LQC        0.451556              NaN
# 48  MC348-3ST1 Appomattox NE         LQC        0.431734              NaN
# 49  MC348-3ST1 Appomattox NE         LQC        0.407153              NaN

# %%
describe_columns(data)
# Out:
# Well name
# 	dtype: object
# 	All: 15956
# 	Unique: 7
# 	Missing: 0
# MC393-1       4029
# MC392-1ST1    3286
# MC391-1       2713
# MC612-1BP1    2175
# MC525-2       1977
# MC392-1       1055
# MC348-3ST1     721
# Name: Well name, dtype: int64
# ****************************************************************************************************
#
# Field
# 	dtype: object
# 	All: 15956
# 	Unique: 4
# 	Missing: 0
# Appomattox      7775
# Vicksburg A     4029
# Dover           2175
# Rydberg Deep    1977
# Name: Field, dtype: int64
# ****************************************************************************************************
#
# Field part
# 	dtype: object
# 	All: 15956
# 	Unique: 4
# 	Missing: 8181
# SE    4341
# SW    2713
# NE     721
# Name: Field part, dtype: int64
# ****************************************************************************************************
#
# MD, ft
# 	dtype: float64
# 	All: 15956
# 	Unique: 11067
# 	Missing: 0
# 	Min: 24463.0
# 	Max: 28694.6030412954
# 	Mean: 26156.911958809298
#
# 25691.000000    4
# 25785.000000    4
# 25667.000000    4
# 25784.000000    4
# 25704.500000    4
#                ..
# 28062.373257    1
# 26425.154297    1
# 25315.000000    1
# 26256.755859    1
# 28352.753818    1
# Name: MD, ft, Length: 11067, dtype: int64
# ****************************************************************************************************
#
# DENSITY, g/cm3
# 	dtype: float64
# 	All: 15956
# 	Unique: 13716
# 	Missing: 373
# 	Min: 2.0708
# 	Max: 3.1126
# 	Mean: 2.2593494001796834
#
# 2.189500    7
# 2.176000    7
# 2.178000    6
# 2.193900    6
# 2.212300    6
#            ..
# 2.280825    1
# 2.306140    1
# 2.267700    1
# 2.392400    1
# 2.369445    1
# Name: DENSITY, g/cm3, Length: 13715, dtype: int64
# ****************************************************************************************************
#
# DTC, us/ft
# 	dtype: float64
# 	All: 15956
# 	Unique: 14359
# 	Missing: 619
# 	Min: 56.17374
# 	Max: 104.7328
# 	Mean: 88.27858117657378
#
# 85.977100    220
# 91.617040      6
# 87.001910      6
# 90.269000      5
# 84.473730      5
#             ...
# 88.450230      1
# 86.050630      1
# 87.256549      1
# 95.419700      1
# 78.314670      1
# Name: DTC, us/ft, Length: 14358, dtype: int64
# ****************************************************************************************************
#
# DTS, US/F
# 	dtype: float64
# 	All: 15956
# 	Unique: 14379
# 	Missing: 750
# 	Min: 91.12006
# 	Max: 192.824
# 	Mean: 151.23615292121534
#
# 159.2103    7
# 132.0829    7
# 151.7681    6
# 133.7256    6
# 167.8416    6
#            ..
# 132.8675    1
# 166.1218    1
# 144.6189    1
# 157.1711    1
# 171.0978    1
# Name: DTS, US/F, Length: 14378, dtype: int64
# ****************************************************************************************************
#
# FLD, unitless
# 	dtype: float64
# 	All: 15956
# 	Unique: 3
# 	Missing: 19
# 	Min: 1.0
# 	Max: 2.0
# 	Mean: 1.8165903244023343
#
# 2.0    13014
# 1.0     2923
# Name: FLD, unitless, dtype: int64
# ****************************************************************************************************
#
# GR, gAPI
# 	dtype: float64
# 	All: 15956
# 	Unique: 15659
# 	Missing: 92
# 	Min: 12.7985
# 	Max: 114.3539
# 	Mean: 33.522515062324295
#
# 25.30820    3
# 31.66770    3
# 27.39840    3
# 35.92370    3
# 28.07796    3
#            ..
# 27.09230    1
# 33.08211    1
# 30.60745    1
# 37.48339    1
# 24.00000    1
# Name: GR, gAPI, Length: 15658, dtype: int64
# ****************************************************************************************************
#
# NEUTRON, CFCF
# 	dtype: float64
# 	All: 15956
# 	Unique: 15162
# 	Missing: 419
# 	Min: 0.09367353
# 	Max: 0.385244
# 	Mean: 0.2676540000567226
#
# 0.291720    3
# 0.287515    3
# 0.153900    3
# 0.161000    3
# 0.302165    3
#            ..
# 0.249401    1
# 0.299580    1
# 0.250905    1
# 0.260799    1
# 0.203125    1
# Name: NEUTRON, CFCF, Length: 15161, dtype: int64
# ****************************************************************************************************
#
# NMR_BW, v/v
# 	dtype: float64
# 	All: 15956
# 	Unique: 14322
# 	Missing: 1562
# 	Min: 1.5e-06
# 	Max: 0.16357170000000001
# 	Mean: 0.0559126068843546
#
# 0.106398    4
# 0.023531    4
# 0.043288    4
# 0.041879    4
# 0.084368    3
#            ..
# 0.066864    1
# 0.030279    1
# 0.025148    1
# 0.102142    1
# 0.059859    1
# Name: NMR_BW, v/v, Length: 14321, dtype: int64
# ****************************************************************************************************
#
# NMR_CBW, v/v
# 	dtype: float64
# 	All: 15956
# 	Unique: 12956
# 	Missing: 1562
# 	Min: 0.0
# 	Max: 0.07770682
# 	Mean: 0.009708142754161457
#
# 0.000000e+00    1138
# 1.960000e-05       6
# 1.300000e-06       6
# 1.360000e-05       5
# 1.000000e-07       5
#                 ...
# 3.991200e-03       1
# 8.863416e-03       1
# 7.540388e-03       1
# 3.302139e-03       1
# 1.580852e-02       1
# Name: NMR_CBW, v/v, Length: 12955, dtype: int64
# ****************************************************************************************************
#
# NMR_FF, v/v
# 	dtype: float64
# 	All: 15956
# 	Unique: 14295
# 	Missing: 1562
# 	Min: 0.0
# 	Max: 0.295275
# 	Mean: 0.1550580460250799
#
# 0.000000    16
# 0.184159     4
# 0.087526     4
# 0.177464     4
# 0.177998     4
#             ..
# 0.123979     1
# 0.152139     1
# 0.130177     1
# 0.080572     1
# 0.204045     1
# Name: NMR_FF, v/v, Length: 14294, dtype: int64
# ****************************************************************************************************
#
# NMR_TPOR, v/v
# 	dtype: float64
# 	All: 15956
# 	Unique: 14283
# 	Missing: 1562
# 	Min: 0.01005928
# 	Max: 0.3392131
# 	Mean: 0.2206717296151174
#
# 0.203282    4
# 0.223365    4
# 0.221509    4
# 0.222409    4
# 0.225139    3
#            ..
# 0.223163    1
# 0.206627    1
# 0.169890    1
# 0.250923    1
# 0.266545    1
# Name: NMR_TPOR, v/v, Length: 14282, dtype: int64
# ****************************************************************************************************
#
# RDEEP, ohm.m
# 	dtype: float64
# 	All: 15956
# 	Unique: 15206
# 	Missing: 21
# 	Min: -0.9041405120060549
# 	Max: 2.0961032135078916
# 	Mean: 0.2713657848653483
#
# -0.500053    6
# -0.472597    5
# -0.613858    5
# -0.543197    5
# -0.547120    5
#             ..
# -0.136011    1
#  0.126553    1
# -0.811634    1
# -0.796423    1
#  0.463908    1
# Name: RDEEP, ohm.m, Length: 15205, dtype: int64
# ****************************************************************************************************
#
# TVD, ft
# 	dtype: float64
# 	All: 15956
# 	Unique: 15589
# 	Missing: 24
# 	Min: 24398.36
# 	Max: 28661.0401761094
# 	Mean: 25588.743723257383
#
# 25381.630000    3
# 25233.630000    3
# 25362.630000    3
# 24923.630000    2
# 25477.130000    2
#                ..
# 25816.270000    1
# 25900.620000    1
# 27595.591484    1
# 25212.790000    1
# 24471.120000    1
# Name: TVD, ft, Length: 15588, dtype: int64
# ****************************************************************************************************
#
# TVDBML, ft
# 	dtype: float64
# 	All: 15956
# 	Unique: 15496
# 	Missing: 0
# 	Min: 16949.04
# 	Max: 21187.0401761094
# 	Mean: 18213.255577772416
#
# 17683.13    4
# 17631.13    3
# 17694.13    3
# 17638.63    3
# 17663.13    3
#            ..
# 17431.85    1
# 17821.66    1
# 17740.13    1
# 18042.41    1
# 17520.67    1
# Name: TVDBML, ft, Length: 15496, dtype: int64
# ****************************************************************************************************
#
# TVDSS, ft
# 	dtype: float64
# 	All: 15956
# 	Unique: 15613
# 	Missing: 0
# 	Min: 24320.04
# 	Max: 28559.0401761094
# 	Mean: 25511.953604220143
#
# 25306.63    3
# 25158.63    3
# 24837.63    3
# 25287.63    3
# 24409.14    2
#            ..
# 25229.96    1
# 24467.95    1
# 25890.62    1
# 25285.17    1
# 24688.67    1
# Name: TVDSS, ft, Length: 15613, dtype: int64
# ****************************************************************************************************
#
# Filename
# 	dtype: object
# 	All: 15956
# 	Unique: 7
# 	Missing: 0
# MC393-1 Vicksburg A_LQC.csv         4029
# MC392-1ST1 Appomattox SE_LQC.csv    3286
# MC391-1 Appomattox SW_LQC.csv       2713
# MC612-1BP1 Dover_LQC.csv            2175
# MC525-2 Rydberg Deep_LQC.csv        1977
# MC392-1 Appomattox SE_LQC.csv       1055
# MC348-3ST1 Appomattox NE_LQC.csv     721
# Name: Filename, dtype: int64
# ****************************************************************************************************
#
# wellName_old
# 	dtype: object
# 	All: 15956
# 	Unique: 7
# 	Missing: 0
# MC393-1 Vicksburg A         4029
# MC392-1ST1 Appomattox SE    3286
# MC391-1 Appomattox SW       2713
# MC612-1BP1 Dover            2175
# MC525-2 Rydberg Deep        1977
# MC392-1 Appomattox SE       1055
# MC348-3ST1 Appomattox NE     721
# Name: wellName_old, dtype: int64
# ****************************************************************************************************
#
# datasetName
# 	dtype: object
# 	All: 15956
# 	Unique: 1
# 	Missing: 0
# LQC    15956
# Name: datasetName, dtype: int64
# ****************************************************************************************************
#
# RMEDIUM, ohm.m
# 	dtype: float64
# 	All: 15956
# 	Unique: 4841
# 	Missing: 11089
# 	Min: -0.8690731009266979
# 	Max: 1.4243457851732664
# 	Mean: -0.1024076488210156
#
# -0.517126    3
#  0.428540    2
#  0.089870    2
#  0.369939    2
# -0.634718    2
#             ..
# -0.676560    1
# -0.328623    1
#  0.450003    1
# -0.067683    1
#  0.118595    1
# Name: RMEDIUM, ohm.m, Length: 4840, dtype: int64
# ****************************************************************************************************
#
# RSHALLOW, ohm.m
# 	dtype: float64
# 	All: 15956
# 	Unique: 8473
# 	Missing: 7463
# 	Min: -0.8545086722402606
# 	Max: 2.0344062399104046
# 	Mean: 0.31258433880688474
#
# -0.512324    3
#  0.496582    2
#  0.604214    2
# -0.564793    2
# -0.149274    2
#             ..
# -0.522618    1
#  0.285262    1
#  0.981866    1
# -0.413424    1
#  0.455772    1
# Name: RSHALLOW, ohm.m, Length: 8472, dtype: int64
# ****************************************************************************************************

# %%
# create a copy of data and scale
# Matt Knuth: Standardizing with mean & std is better than minmax scaling because it can preserve more data
data_original = deepcopy(data)
to_stay = ['Well name', 'Field', 'Field part', 'Filename', 'wellName_old', 'datasetName',
          'TVD, ft', 'TVDBML, ft', 'TVDSS, ft', 'MD, ft', 'FLD, unitless']
to_scale = [col for col in data.columns if col not in to_stay]

scaler = StandardScaler()
data[to_scale] = scaler.fit_transform(data[to_scale])

# %%
data.head(50)
# Out:
#      Well name       Field Field part    MD, ft  DENSITY, g/cm3  DTC, us/ft  \
# 0   MC348-3ST1  Appomattox         NE  25654.00       11.810724   -3.282618
# 1   MC348-3ST1  Appomattox         NE  25654.25       11.862163   -3.241252
# 2   MC348-3ST1  Appomattox         NE  25654.50       11.349167   -3.199886
# 3   MC348-3ST1  Appomattox         NE  25654.75       10.406590   -3.159990
# 4   MC348-3ST1  Appomattox         NE  25655.00        9.138699   -3.120095
# 5   MC348-3ST1  Appomattox         NE  25655.25        6.722475   -3.104825
# 35    17892.51   25148.51  MC348-3ST1 Appomattox NE_LQC.csv
# 36    17892.73   25148.73  MC348-3ST1 Appomattox NE_LQC.csv
# 37    17892.95   25148.95  MC348-3ST1 Appomattox NE_LQC.csv
# 38    17893.17   25149.17  MC348-3ST1 Appomattox NE_LQC.csv
# 39    17893.39   25149.39  MC348-3ST1 Appomattox NE_LQC.csv
# 40    17893.61   25149.61  MC348-3ST1 Appomattox NE_LQC.csv
# 41    17893.83   25149.83  MC348-3ST1 Appomattox NE_LQC.csv
# 42    17894.05   25150.05  MC348-3ST1 Appomattox NE_LQC.csv
# 43    17894.27   25150.27  MC348-3ST1 Appomattox NE_LQC.csv
# 44    17894.49   25150.49  MC348-3ST1 Appomattox NE_LQC.csv
# 45    17894.71   25150.71  MC348-3ST1 Appomattox NE_LQC.csv
# 46    17894.93   25150.93  MC348-3ST1 Appomattox NE_LQC.csv
# 47    17895.15   25151.15  MC348-3ST1 Appomattox NE_LQC.csv
# 48    17895.37   25151.37  MC348-3ST1 Appomattox NE_LQC.csv
# 49    17895.59   25151.59  MC348-3ST1 Appomattox NE_LQC.csv
#
#                 wellName_old datasetName  RMEDIUM, ohm.m  RSHALLOW, ohm.m
# 0   MC348-3ST1 Appomattox NE         LQC        3.532304              NaN
# 1   MC348-3ST1 Appomattox NE         LQC        3.514227              NaN
# 2   MC348-3ST1 Appomattox NE         LQC        3.135936              NaN
# 3   MC348-3ST1 Appomattox NE         LQC        2.886046              NaN
# 4   MC348-3ST1 Appomattox NE         LQC        2.768231              NaN
# 5   MC348-3ST1 Appomattox NE         LQC        2.730333              NaN
# 6   MC348-3ST1 Appomattox NE         LQC        2.728542              NaN
# 7   MC348-3ST1 Appomattox NE         LQC        2.653347              NaN
# 8   MC348-3ST1 Appomattox NE         LQC        2.587729              NaN
# 9   MC348-3ST1 Appomattox NE         LQC        2.551199              NaN
# 10  MC348-3ST1 Appomattox NE         LQC        2.557156              NaN
# 11  MC348-3ST1 Appomattox NE         LQC        2.594100              NaN
# 12  MC348-3ST1 Appomattox NE         LQC        2.572028              NaN
# 13  MC348-3ST1 Appomattox NE         LQC        2.533359              NaN
# 14  MC348-3ST1 Appomattox NE         LQC        2.513029              NaN
# 15  MC348-3ST1 Appomattox NE         LQC        2.487819              NaN
# 16  MC348-3ST1 Appomattox NE         LQC        2.466154              NaN
# 17  MC348-3ST1 Appomattox NE         LQC        2.453873              NaN
# 18  MC348-3ST1 Appomattox NE         LQC        2.428056              NaN
# 19  MC348-3ST1 Appomattox NE         LQC        2.414595              NaN
# 20  MC348-3ST1 Appomattox NE         LQC        2.392439              NaN
# 21  MC348-3ST1 Appomattox NE         LQC        2.353375              NaN
# 22  MC348-3ST1 Appomattox NE         LQC        2.314232              NaN
# 23  MC348-3ST1 Appomattox NE         LQC        2.283657              NaN
# 24  MC348-3ST1 Appomattox NE         LQC        2.250011              NaN
# 25  MC348-3ST1 Appomattox NE         LQC        2.217427              NaN
# 26  MC348-3ST1 Appomattox NE         LQC        2.190531              NaN
# 27  MC348-3ST1 Appomattox NE         LQC        2.145258              NaN
# 28  MC348-3ST1 Appomattox NE         LQC        2.103039              NaN
# 29  MC348-3ST1 Appomattox NE         LQC        2.064279              NaN
# 30  MC348-3ST1 Appomattox NE         LQC        2.021790              NaN
# 31  MC348-3ST1 Appomattox NE         LQC        1.988297              NaN
# 32  MC348-3ST1 Appomattox NE         LQC        1.949710              NaN
# 33  MC348-3ST1 Appomattox NE         LQC        1.911709              NaN
# 34  MC348-3ST1 Appomattox NE         LQC        1.853649              NaN
# 35  MC348-3ST1 Appomattox NE         LQC        1.814665              NaN
# 36  MC348-3ST1 Appomattox NE         LQC        1.781888              NaN
# 37  MC348-3ST1 Appomattox NE         LQC        1.733904              NaN
# 38  MC348-3ST1 Appomattox NE         LQC        1.687079              NaN
# 39  MC348-3ST1 Appomattox NE         LQC        1.649486              NaN
# 40  MC348-3ST1 Appomattox NE         LQC        1.594140              NaN
# 41  MC348-3ST1 Appomattox NE         LQC        1.540054              NaN
# 42  MC348-3ST1 Appomattox NE         LQC        1.513276              NaN
# 43  MC348-3ST1 Appomattox NE         LQC        1.473866              NaN
# 44  MC348-3ST1 Appomattox NE         LQC        1.415149              NaN
# 45  MC348-3ST1 Appomattox NE         LQC        1.348708              NaN
# 46  MC348-3ST1 Appomattox NE         LQC        1.320604              NaN
# 47  MC348-3ST1 Appomattox NE         LQC        1.281653              NaN
# 48  MC348-3ST1 Appomattox NE         LQC        1.235792              NaN
# 49  MC348-3ST1 Appomattox NE         LQC        1.178922              NaN

# %%
describe_columns(data)
# Out:
# Well name
# 	dtype: object
# 	All: 15956
# 	Unique: 7
# 	Missing: 0
# MC393-1       4029
# MC392-1ST1    3286
# MC391-1       2713
# MC612-1BP1    2175
# MC525-2       1977
# MC392-1       1055
# MC348-3ST1     721
# Name: Well name, dtype: int64
# ****************************************************************************************************
#
# Field
# 	dtype: object
# 	All: 15956
# 	Unique: 4
# 	Missing: 0
# Appomattox      7775
# Vicksburg A     4029
# Dover           2175
# Rydberg Deep    1977
# Name: Field, dtype: int64
# ****************************************************************************************************
#
# Field part
# 	dtype: object
# 	All: 15956
# 	Unique: 4
# 	Missing: 8181
# SE    4341
# SW    2713
# NE     721
# Name: Field part, dtype: int64
# ****************************************************************************************************
#
# MD, ft
# 	dtype: float64
# 	All: 15956
# 	Unique: 11067
# 	Missing: 0
# 	Min: 24463.0
# 	Max: 28694.6030412954
# 	Mean: 26156.911958809298
#
# 25691.000000    4
# 25785.000000    4
# 25667.000000    4
# 25784.000000    4
# 25704.500000    4
#                ..
# 28062.373257    1
# 26425.154297    1
# 25315.000000    1
# 26256.755859    1
# 28352.753818    1
# Name: MD, ft, Length: 11067, dtype: int64
# ****************************************************************************************************
#
# DENSITY, g/cm3
# 	dtype: float64
# 	All: 15956
# 	Unique: 13716
# 	Missing: 373
# 	Min: -2.6212741325744306
# 	Max: 11.862163039400714
# 	Mean: -6.361735384280894e-15
#
# -0.971069    7
# -1.158750    7
# -0.654096    6
# -0.909899    6
# -1.130945    6
#             ..
# -1.093075    1
# -0.575284    1
#  0.604606    1
# -0.285239    1
# -0.980995    1
# Name: DENSITY, g/cm3, Length: 13715, dtype: int64
# ****************************************************************************************************
#
# DTC, us/ft
# 	dtype: float64
# 	All: 15956
# 	Unique: 14359
# 	Missing: 619
# 	Min: -4.877884865238289
# 	Max: 2.499990095782658
# 	Mean: 1.1267131338387975e-15
#
# -0.349678    220
# -0.193972      6
#  0.507232      6
#  0.740637      5
#  0.879095      5
#             ...
# -0.834213      1
# -0.242887      1
#  0.026428      1
#  0.877750      1
# -0.872343      1
# Name: DTC, us/ft, Length: 14358, dtype: int64
# ****************************************************************************************************
#
# DTS, US/F
# 	dtype: float64
# 	All: 15956
# 	Unique: 14379
# 	Missing: 750
# 	Min: -3.8950034041074617
# 	Max: 2.694533161921463
# 	Mean: -1.7270590236546956e-15
#
# -1.240965    7
#  0.516656    7
#  0.969256    6
#  0.755263    6
# -1.134533    6
#             ..
#  0.287690    1
#  0.972068    1
# -0.546110    1
#  0.530638    1
#  0.139123    1
# Name: DTS, US/F, Length: 14378, dtype: int64
# ****************************************************************************************************
#
# FLD, unitless
# 	dtype: float64
# 	All: 15956
# 	Unique: 3
# 	Missing: 19
# 	Min: 1.0
# 	Max: 2.0
# 	Mean: 1.8165903244023343
#
# 2.0    13014
# 1.0     2923
# Name: FLD, unitless, dtype: int64
# ****************************************************************************************************
#
# GR, gAPI
# 	dtype: float64
# 	All: 15956
# 	Unique: 15659
# 	Missing: 92
# 	Min: -3.40320349104543
# 	Max: 13.273762375613849
# 	Mean: 1.576595076825235e-16
#
# -0.894080    3
# -0.142164    3
#  0.394312    3
# -1.005674    3
# -0.304589    3
#             ..
# -0.713096    1
# -0.659853    1
# -0.699642    1
# -1.283560    1
#  0.198091    1
# Name: GR, gAPI, Length: 15658, dtype: int64
# ****************************************************************************************************
#
# NEUTRON, CFCF
# 	dtype: float64
# 	All: 15956
# 	Unique: 15162
# 	Missing: 419
# 	Min: -4.410345904514593
# 	Max: 2.980866613894205
# 	Mean: -1.478067916571181e-15
#
# -2.713783    3
# -1.935548    3
#  0.503470    3
# -2.741667    3
# -2.846868    3
#             ..
# -0.716767    1
# -1.927717    1
# -0.332337    1
# -0.904780    1
#  1.639565    1
# Name: NEUTRON, CFCF, Length: 15161, dtype: int64
# ****************************************************************************************************
#
# NMR_BW, v/v
# 	dtype: float64
# 	All: 15956
# 	Unique: 14322
# 	Missing: 1562
# 	Min: -2.162334574420803
# 	Max: 4.163662504057685
# 	Mean: -2.5274272662857533e-16
#
# -0.542725    4
#  1.952490    4
# -1.252348    4
# -0.488239    4
#  1.391200    3
#             ..
# -0.424192    1
#  0.344489    1
# -0.841523    1
# -0.572491    1
# -0.838386    1
# Name: NMR_BW, v/v, Length: 14321, dtype: int64
# ****************************************************************************************************
#
# NMR_CBW, v/v
# 	dtype: float64
# 	All: 15956
# 	Unique: 12956
# 	Missing: 1562
# 	Min: -0.9183515723816961
# 	Max: 6.43240357604168
# 	Mean: -4.738926124285787e-17
#
# -0.918352    1138
# -0.918229       6
# -0.916497       6
# -0.917065       5
# -0.918342       5
#              ...
# -0.250661       1
#  4.128490       1
# -0.304468       1
#  0.640996       1
#  3.366813       1
# Name: NMR_CBW, v/v, Length: 12955, dtype: int64
# ****************************************************************************************************
#
# NMR_FF, v/v
# 	dtype: float64
# 	All: 15956
# 	Unique: 14295
# 	Missing: 1562
# 	Min: -3.0723786541044644
# 	Max: 2.7783116541170196
# 	Mean: 1.5796420414285957e-16
#
# -3.072379    16
#  0.443970     4
#  0.454539     4
#  0.576611     4
# -1.338108     4
#              ..
#  1.128390     1
#  0.032588     1
# -0.201854     1
#  0.539812     1
#  1.139120     1
# Name: NMR_FF, v/v, Length: 14294, dtype: int64
# ****************************************************************************************************
#
# NMR_TPOR, v/v
# 	dtype: float64
# 	All: 15956
# 	Unique: 14283
# 	Missing: 1562
# 	Min: -5.031838397305768
# 	Max: 2.8321261172448877
# 	Mean: -6.318568165714383e-17
#
#  0.041518    4
#  0.020008    4
#  0.064346    4
# -0.415471    4
# -0.764592    3
#             ..
# -2.043972    1
# -0.269150    1
# -0.144298    1
# -1.494378    1
#  0.112743    1
# Name: NMR_TPOR, v/v, Length: 14282, dtype: int64
# ****************************************************************************************************
#
# RDEEP, ohm.m
# 	dtype: float64
# 	All: 15956
# 	Unique: 15206
# 	Missing: 21
# 	Min: -2.1800466758134633
# 	Max: 3.384084607740528
# 	Mean: 0.0
#
# -1.430642    6
# -1.488834    5
# -1.503382    5
# -1.641700    5
# -1.554301    5
#             ..
#  0.464115    1
#  1.726695    1
#  1.263585    1
# -0.084552    1
#  0.445211    1
# Name: RDEEP, ohm.m, Length: 15205, dtype: int64
# ****************************************************************************************************
#
# TVD, ft
# 	dtype: float64
# 	All: 15956
# 	Unique: 15589
# 	Missing: 24
# 	Min: 24398.36
# 	Max: 28661.0401761094
# 	Mean: 25588.743723257383
#
# 25381.630000    3
# 25233.630000    3
# 25362.630000    3
# 24923.630000    2
# 25477.130000    2
#                ..
# 25816.270000    1
# 25900.620000    1
# 27595.591484    1
# 25212.790000    1
# 24471.120000    1
# Name: TVD, ft, Length: 15588, dtype: int64
# ****************************************************************************************************
#
# TVDBML, ft
# 	dtype: float64
# 	All: 15956
# 	Unique: 15496
# 	Missing: 0
# 	Min: 16949.04
# 	Max: 21187.0401761094
# 	Mean: 18213.255577772416
#
# 17683.13    4
# 17631.13    3
# 17694.13    3
# 17638.63    3
# 17663.13    3
#            ..
# 17431.85    1
# 17821.66    1
# 17740.13    1
# 18042.41    1
# 17520.67    1
# Name: TVDBML, ft, Length: 15496, dtype: int64
# ****************************************************************************************************
#
# TVDSS, ft
# 	dtype: float64
# 	All: 15956
# 	Unique: 15613
# 	Missing: 0
# 	Min: 24320.04
# 	Max: 28559.0401761094
# 	Mean: 25511.953604220143
#
# 25306.63    3
# 25158.63    3
# 24837.63    3
# 25287.63    3
# 24409.14    2
#            ..
# 25229.96    1
# 24467.95    1
# 25890.62    1
# 25285.17    1
# 24688.67    1
# Name: TVDSS, ft, Length: 15613, dtype: int64
# ****************************************************************************************************
#
# Filename
# 	dtype: object
# 	All: 15956
# 	Unique: 7
# 	Missing: 0
# MC393-1 Vicksburg A_LQC.csv         4029
# MC392-1ST1 Appomattox SE_LQC.csv    3286
# MC391-1 Appomattox SW_LQC.csv       2713
# MC612-1BP1 Dover_LQC.csv            2175
# MC525-2 Rydberg Deep_LQC.csv        1977
# MC392-1 Appomattox SE_LQC.csv       1055
# MC348-3ST1 Appomattox NE_LQC.csv     721
# Name: Filename, dtype: int64
# ****************************************************************************************************
#
# wellName_old
# 	dtype: object
# 	All: 15956
# 	Unique: 7
# 	Missing: 0
# MC393-1 Vicksburg A         4029
# MC392-1ST1 Appomattox SE    3286
# MC391-1 Appomattox SW       2713
# MC612-1BP1 Dover            2175
# MC525-2 Rydberg Deep        1977
# MC392-1 Appomattox SE       1055
# MC348-3ST1 Appomattox NE     721
# Name: wellName_old, dtype: int64
# ****************************************************************************************************
#
# datasetName
# 	dtype: object
# 	All: 15956
# 	Unique: 1
# 	Missing: 0
# LQC    15956
# Name: datasetName, dtype: int64
# ****************************************************************************************************
#
# RMEDIUM, ohm.m
# 	dtype: float64
# 	All: 15956
# 	Unique: 4841
# 	Missing: 11089
# 	Min: -1.7737609950899904
# 	Max: 3.5323043224405732
# 	Mean: -2.335870920929033e-17
#
# -0.959495    3
# -1.227620    2
# -1.227707    2
# -0.452285    2
#  1.141482    2
#             ..
# -1.579221    1
#  0.755848    1
# -1.168442    1
# -1.084192    1
# -0.945187    1
# Name: RMEDIUM, ohm.m, Length: 4840, dtype: int64
# ****************************************************************************************************
#
# RSHALLOW, ohm.m
# 	dtype: float64
# 	All: 15956
# 	Unique: 8473
# 	Missing: 7463
# 	Min: -1.9754849690293936
# 	Max: 2.9144491936626085
# 	Mean: 0.0
#
# -1.396285    3
#  0.311445    2
# -1.668754    2
# -1.615988    2
# -1.485096    2
#             ..
# -0.630153    1
# -1.006260    1
# -1.525264    1
#  0.143436    1
# -1.573438    1
# Name: RSHALLOW, ohm.m, Length: 8472, dtype: int64
# ****************************************************************************************************

# %%
data_original.to_csv('norphlet_original.csv', index=False, encoding='utf8')
data.to_csv('norphlet_scaled.csv', index=False, encoding='utf8')

# %% [markdown]
# __Recommendations by Matt Knuth (05/04/2020 & 05/24/2020)__
# * We should be able to classify what we see (Matt's words)
# * Standardizing with mean & std is better than minmax scaling because it can preserve more data, but take the lg_10 of resistivity. Do it for all the wells
# * Dover well's top is good, bottom bad (NMR_FF - poor quality), there is also a water leg - look for FLD (fluid) 1
# Split the scope of work by task, not by wells
# * Segmentation within one well - look at the variability of data (five 50-feet segments in one well are representative to describe this well) - if I am trying to classify this, what is a representative interval (top 100 feet in this well (don't need the NMR for this, only GR, D, R' reason - NMR_TPOR is correlated with D; if use NMR, then it should be NMR_FF because it remove microporosity; assigning weights can also help, e.g. NMR_FF + NMR_ = NMR_TPOR
# * Depositional facies vary by 5 ft - resolution too small, but if we find that these 100 feet are better quality, we can segment it this way
# * 3921st1, 3931 deviated; in FLD column, 2 = oil, 1 = water
#
# * All logs are correlated with porosity - use the ratio DTC / DTS because it will less sensitive to it
# * NMR_FF may be dependent on e.g. DTC / DTS and resistivity
# * Matt to provide stratigraphic subzones, climatic zones, formulat to estimate permeability, but don't use the formula because it's a derived value and it will be correlated with the existing logs anyway
